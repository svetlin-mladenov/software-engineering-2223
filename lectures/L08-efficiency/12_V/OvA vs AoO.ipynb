# %% [markdown]
# AoO
# ---

# %%
from random import choice

class Student:
    def __init__(self, name, age, mark):
        self.name = name
        self.age = age
        self.mark = mark

students = []
for i in range(1_000_000):
    students.append(Student(f"Name {i}", 18, choice([2, 3, 4, 5, 6])))

# %%
def avg_mark(students):
    sum_marks = 0
    for student in students:
        sum_marks += student.mark
    return sum_marks / len(students)

# %%
# %%timeit
avg_mark(students)
# Out:
# 69.2 ms ± 4.54 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# OoA
# ---

# %%
class Students:
    def __init__(self):
        self.names = []
        self.ages = []
        self.marks = []

students = Students()
for i in range(1_000_000):
    students.names.append(f"Name {i}")
    students.ages.append(18)
    students.marks.append(choice([2, 3, 4, 5, 6]))

# %%
def avg_mark(students):
    sum_marks = 0
    for mark in students.marks:
        sum_marks += mark
    return sum_marks / len(students.marks)

# %%
# %%timeit
avg_mark(students)
# Out:
# 41.5 ms ± 3.01 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# List comp
# ---

# %%
[i**2 for i in range(10)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
students = []
for i in range(1_000_000):
    students.append(Student(f"Name {i}", 18, choice([2, 3, 4, 5, 6])))

# %%
students = [
    Student(f"Name {i}", 18, choice([2, 3, 4, 5, 6]))
    for i in range(1_000_000)
]

# %%
def cond(i):
    return (i+i//2) % 3 == 0

# %%
[i**i for  i in range(5, 5000) if cond(i)]
# Out:
# [46656,
#  16777216,
#  10000000000,
#  8916100448256,
#  11112006825558016,
#  18446744073709551616,
#  39346408075296537575424,
#  104857600000000000000000000,
#  341427877364219557396646723584,
#  1333735776850284124449081472843776,
#  6156119580207157310796674288400203776,
#  33145523113253374862572728253364605812736,
#  205891132094649000000000000000000000000000000,
#  1461501637330902918203684832716283019655932542976,
#  11756638905368616011414050501310355554617941909569536,
#  106387358923716524807713475752456393740167855629859291136,
#  1075911801979993982060429252856123779115487368830416064610304,
#  12089258196146291747061760000000000000000000000000000000000000000,
#  150130937545296572356771972164254457814047970568738777235893533016064,
#  2050773823560610053645205609172376035486179836520607547294916966189367296,
#  30680346300794274230660433647640397899788170645078853280082659754365153181696,
# ...

# %% [markdown]
# Str Concat
# ---

# %%
str_arr = ["Pesho", "Gosho", "Ivan", "Dragan", "Sasho"]

# %%
"Filan, " + ", ".join(str_arr)
# Out:
# 'Filan, Pesho, Gosho, Ivan, Dragan, Sasho'

# %%
", ".join(["Filan"] + str_arr)
# Out:
# 'Filan, Pesho, Gosho, Ivan, Dragan, Sasho'
